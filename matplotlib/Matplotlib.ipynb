# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Titanic-Dataset.csv', index_col='PassengerId') # Прочитали файл csv
# df = df.set_index('PassengerId') # Переопределили строку индексации данных на свою
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
df.isnull().sum().sum() # Количество пустых ячеек во всей таблице
# Out:
# 866

# %%
df['Age'] = df['Age'].fillna(df.mean(axis=1)) # Замена пустоты в колонке Age средним значением
df
# Out:
# <ipython-input-31-47e392654d9b>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['Age'] = df['Age'].fillna(df.mean(axis=1)) # Замена пустоты в колонке Age средним значением
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex    Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.00
# ...

# %%
df = df.fillna(method='ffill') # Для остальных колонок заполнили пустоты предыдущим значением
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   C85        S
# ...

# %%
df = df.fillna(method='bfill') # Для остальных колонок заполнили пустоты следующим значением
df1 = df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       891 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     891 non-null    object
#  10  Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
uniques = pd.unique(df.values.ravel()) # Уникальные значения всей таблицы
len(uniques) # Кол-во уникальных значений
# Out:
# 2119

# %%
df.describe() # Статистика по всем столбцам кол-во строк,  среднее значение, стандартные отклонения значений в кадре данных, минимальное
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   24.824224    0.523008    0.381594   32.204208
# std      0.486592    0.836071   16.530957    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.200000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   11.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   24.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Получим максимальные значения в каждом столбце
maximums = df.max()
maximums
# Out:
# Survived                              1
# Pclass                                3
# Name        van Melkebeke, Mr. Philemon
# Sex                                male
# Age                                80.0
# SibSp                                 8
# Parch                                 6
# Ticket                        WE/P 5735
# Fare                           512.3292
# Cabin                                 T
# Embarked                              S
# dtype: object

# %%
df['Age'].max() #Максимум в столбце Age
# Out:
# 80.0

# %%
# Получим минимальные значения в каждом столбце
minimums = df.min()
minimums
# Out:
# Survived                      0
# Pclass                        1
# Name        Abbing, Mr. Anthony
# Sex                      female
# Age                         0.2
# SibSp                         0
# Parch                         0
# Ticket                   110152
# Fare                        0.0
# Cabin                       A10
# Embarked                      C
# dtype: object

# %%
df['Age'].min() # Минимум в столбце Age
# Out:
# 0.2

# %%
# Конвертируем колонку с возрастом в тип Int
df1['Age'] = df1['Age'].astype(int)
df1['Age'].head()
# Out:
# PassengerId
# 1    22
# 2    38
# 3    26
# 4    35
# 5    35
# Name: Age, dtype: int64

# %%
# Разбиваем возраст на интервалы в новой колонке по 10 лет(до 90 лет)
df1['Age Group'] = pd.cut(df1['Age'], bins=range(0, 91, 10))
# df1['Age Group']
df1.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                                       Heikkinen, Miss. Laina  female   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 5                                     Allen, Mr. William Henry    male   35
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked Age Group
# PassengerId
# 1                1      0         A/5 21171   7.2500   C85        S  (20, 30]
# 2                1      0          PC 17599  71.2833   C85        C  (30, 40]
# ...

# %%
df1['Survived'].value_counts(dropna=False)  #Кол-во погибших/выживших, dropna=False это не сбрасывать незаполненные значения
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
survival = df1.groupby('Survived')['Survived'].value_counts().unstack(fill_value=0)
survival.plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
# # Выживаемость по Годам (Age)
survived_died_counts = df1.groupby(['Age', 'Survived']).size().unstack()
survived_died_counts
# Out:
# Survived     0     1
# Age
# 0          8.0   7.0
# 1          4.0   5.0
# 2         77.0  23.0
# 3         11.0   8.0
# 4          7.0  14.0
# ..         ...   ...
# 66         1.0   NaN
# 70         3.0   NaN
# 71         2.0   NaN
# 74         1.0   NaN
# 80         NaN   1.0
#
# [71 rows x 2 columns]

# %%
sns.jointplot(df1['Age'], kind='hex')

# %%
# Группировка выживших/не выживших по возрастам, с интервалом в 10 лет
survived_died_counts = df1.groupby(['Age Group', 'Survived']).size().unstack()
survived_died_counts['sum_people'] = survived_died_counts.sum(axis=1) # всего человек в интервалах в новой колонке sum_people
survived_died_counts
# Out:
# Survived     0   1  sum_people
# Age Group
# (0, 10]    133  73         206
# (10, 20]    80  51         131
# (20, 30]   147  87         234
# (30, 40]    86  69         155
# (40, 50]    53  33          86
# (50, 60]    25  17          42
# (60, 70]    14   4          18
# (70, 80]     3   1           4
# (80, 90]     0   0           0

# %%
survived_died_counts.plot.bar(figsize=(6,4)).autoscale(enable=True,axis='both',tight=True)

# %%
x = df1['Age']
y = df1['Sex']
# sns.boxplot(x,y,hue="Survived",data=df1) # ~ GROUP BY Survived

# %%
sns.boxplot(x='Sex', y ='Age', hue='Survived', data=df1)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# *Вывод: больше всего выжило в процентном соотношении людей в возрасте 30-40 лет*

# %%
# Выживаемость по Классу Круиза (Pclass)
survival_Pclass = df.groupby('Pclass')['Survived'].value_counts().unstack(fill_value=0)
survival_Pclass['sum_people'] = survival_Pclass.sum(axis=1)
survival_Pclass
# Out:
# Survived    0    1  sum_people
# Pclass
# 1          80  136         216
# 2          97   87         184
# 3         372  119         491

# %%
survival_Pclass.plot.bar(figsize=(6,4)).autoscale(enable=True,axis='both',tight=True)

# %% [markdown]
# *Вывод: больше всего выжило людей в 1 классе*

# %%
# # Выживаемость по половому признаку (sex)
survival_by_sex = df.groupby('Sex')['Survived'].value_counts().unstack(fill_value=0)
survival_by_sex['total_people'] = survival_by_sex.sum(axis=1)
survival_by_sex
# Out:
# Survived    0    1  total_people
# Sex
# female     81  233           314
# male      468  109           577

# %%
survival_by_sex.plot.bar(figsize=(6,4)).autoscale(enable=True,axis='both',tight=True)

# %%
survival_by_sex = df1.groupby('Sex')['Survived'].value_counts().unstack(fill_value=0)
survival_by_sex.plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %% [markdown]
# *Вывод: больше всего выжило женского пола*

# %%
# # Выживаемость по числу братьев,сестер или супругов на борту у человека (SibSp)
survival_by_SibSP = df.groupby('SibSp')['Survived'].value_counts().unstack(fill_value=0)
survival_by_SibSP['sum_people'] = survival_by_SibSP.sum(axis=1)
survival_by_SibSP
# Out:
# Survived    0    1  sum_people
# SibSp
# 0         398  210         608
# 1          97  112         209
# 2          15   13          28
# 3          12    4          16
# 4          15    3          18
# 5           5    0           5
# 8           7    0           7

# %%
survival_by_SibSP.plot.bar(figsize=(6,4)).autoscale(enable=True,axis='both',tight=True)

# %% [markdown]
# *Вывод: чем меньше братьев тем больше шанс выжить*

# %%
# Выживаемость по количеству родителей или детей, с которыми путешествовал каждый пассажир (Parch)
survival_by_Parch = df.groupby('Parch')['Survived'].value_counts().unstack(fill_value=0)
survival_by_Parch['Count_people'] = survival_by_Parch.sum(axis=1)
survival_by_Parch
# Out:
# Survived    0    1  Count_people
# Parch
# 0         445  233           678
# 1          53   65           118
# 2          40   40            80
# 3           2    3             5
# 4           4    0             4
# 5           4    1             5
# 6           1    0             1

# %%
survival_by_Parch.plot.bar(figsize=(6,4)).autoscale(enable=True,axis='both',tight=True)

# %% [markdown]
# *Вывод: больше всего выжило людей кто был без родителей и детей*

# %%
# Выживаемость по номеру билета (Ticket)
survival_by_Ticket = df.groupby('Ticket')['Survived'].value_counts().unstack(fill_value=0)
survival_by_Ticket['count_people_buy'] = survival_by_Ticket.sum(axis=1)
survival_by_Ticket
# Out:
# Survived     0  1  count_people_buy
# Ticket
# 110152       0  3                 3
# 110413       1  2                 3
# 110465       2  0                 2
# 110564       0  1                 1
# 110813       0  1                 1
# ...         .. ..               ...
# W./C. 6608   4  0                 4
# W./C. 6609   1  0                 1
# W.E.P. 5734  1  0                 1
# W/C 14208    1  0                 1
# WE/P 5735    1  1                 2
#
# [681 rows x 3 columns]

# %%
survival_by_Ticket.plot.bar(figsize=(6,4)).autoscale(enable=True,axis='both',tight=True)

# %%
# Выживаемость по цене билета (Fare)
survival_by_Fare = df.groupby('Fare')['Survived'].value_counts().unstack(fill_value=0)
survival_by_Fare['Count_people_buy'] = survival_by_Fare.sum(axis=1)
survival_by_Fare
# Out:
# Survived   0  1  Count_people_buy
# Fare
# 0.0000    14  1                15
# 4.0125     1  0                 1
# 5.0000     1  0                 1
# 6.2375     1  0                 1
# 6.4375     1  0                 1
# ...       .. ..               ...
# 227.5250   1  3                 4
# 247.5208   1  1                 2
# 262.3750   0  2                 2
# 263.0000   2  2                 4
# 512.3292   0  3                 3
#
# [248 rows x 3 columns]

# %%
survival_by_Fare.plot.bar(figsize=(6,4)).autoscale(enable=True,axis='both',tight=True)

# %%
# Выживаемость по номеру каюты (Cabin)
survival_by_Cabin = df.groupby('Cabin')['Survived'].value_counts().unstack(fill_value=0)
survival_by_Cabin['sum_people'] = survival_by_Cabin.sum(axis=1)
survival_by_Cabin
# Out:
# Survived   0  1  sum_people
# Cabin
# A10        2  0           2
# A14        7  2           9
# A16        1  1           2
# A19        3  4           7
# A20        5  5          10
# ...       .. ..         ...
# F33       10  9          19
# F38        2  1           3
# F4         2  3           5
# G6        17  7          24
# T          1  0           1
#
# [147 rows x 3 columns]

# %%
survival_by_Cabin.plot.bar(figsize=(6,4)).autoscale(enable=True,axis='both',tight=True)

# %%
# Выживаемость по порту посадки (Embarked)
survival_by_Embarked = df.groupby('Embarked')['Survived'].value_counts().unstack(fill_value=0)
survival_by_Embarked['sum_people'] = survival_by_Embarked.sum(axis=1)
survival_by_Embarked
# Out:
# Survived    0    1  sum_people
# Embarked
# C          75   94         169
# Q          47   31          78
# S         427  217         644

# %%
survival_by_Embarked.plot.bar(figsize=(6,4)).autoscale(enable=True,axis='both',tight=True)

# %% [markdown]
# *Вывод: больше всего выжило людей кто был из порта С (в % соотношении)*
